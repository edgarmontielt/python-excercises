# %%
import math

def generarLista(x):
    tamaño = int(input('Tamaño de la lista: '))
    for i in range(0, tamaño):
        numero = int(input('Ingresa un número: '))
        x.append(numero)

def media(lista):
    total = 0
    for i in range(0,len(lista)):
        total = total + lista[i]

    return total/len(lista)

def varianza(lista):
    varianz = 0
    for i in range(0, len(lista)):
        varianz = varianz + pow(lista[i],2)
    return varianz / len(lista) - pow(media(lista),2)

def desviacionTip(r):
    return math.sqrt(varianza(r))

a = []
generarLista(a)
print('Tu conjunto de números es: ', a)
print('Media: ' , media(a))
print('Varianza:' , varianza(a))
print('Desviación tipica: ' , desviacionTip(a))
# Out:
# Tamaño de la lista: 10
# Ingresa un número: 6
# Ingresa un número: 3
# Ingresa un número: 4
# Ingresa un número: 5
# Ingresa un número: 2
# Ingresa un número: 4
# Ingresa un número: 3
# Ingresa un número: 4
# Ingresa un número: 2
# Ingresa un número: 7
# Tu conjunto de números es:  [6, 3, 4, 5, 2, 4, 3, 4, 2, 7]
# Media:  4.0
# Varianza: 2.3999999999999986
# Desviación tipica:  1.5491933384829664
