# %%
print('Bienvenido a la Cafetería "  "')

desicion = 'Si'

while desicion == 'Si':
    print('Seleccione la opción a escoger (Ingrese el número): \n1. Cafes: \n2. Cuernitos \n3. Postres: ')
    opc = int(input())
    
    if opc == 1:
        
        print('Los cafés disponibles son: \n1. Caliente: $25  \n2. Frío: $25 \n3. Frappe: $30')
        tipo = int(input('Para escoger, ingresa el número: '))
        
        if tipo == 1:
            caliente = 25
            print('El total a pagar es: $', caliente)
            desicion = input("¿Desea algo más?")
        elif tipo == 2: 
            frio = 25
            print('El total a pagar es: $', frio)
            desicion = input("¿Desea algo más?")
        elif tipo == 3: 
            frappe = 25
            print('El total a pagar es: $', frappe)
            desicion = input("¿Desea algo más?")
        else: 
            print()
            print('El valor ingresado no esta dentro del rango. Pruebe de nuevo')
            desicion = 'Si'
            
    elif opc == 2: 
        
        print('Los cuernitos disponibles son: \n1. Atún: $25  \n2. Jamón y queso: $25 \n3. Carne y queso: $30')
        tipo = int(input('Para escoger, ingresa el número: '))
        
        if tipo == 1:
            atun = 20
            print('El total a pagar es: $', atun)
            desicion = input("¿Desea algo más?")
        elif tipo == 2: 
            jam_queso = 25
            print('El total a pagar es: $', jam_queso)
            desicion = input("¿Desea algo más?")
        elif tipo == 3: 
            carn_queso = 30
            print('El total a pagar es: $', carn_queso)
            desicion = input("¿Desea algo más?")
        else: 
            print()
            print('El valor ingresado no esta dentro del rango. Pruebe de nuevo')
            desicion = 'Si'
        
    elif opc == 3: 
        
        print('Los postres disponibles son: \n1. Pastel de Chocolate: $25  \n2. Pastel de elote: $25 \n3. Pay de queso: $30')
        tipo = int(input('Para escoger, ingresa el número: '))
        
        if tipo == 1:
            caliente = 25
            print('El total a pagar es: $', caliente)
            desicion = input("¿Desea algo más?")
        elif tipo == 2: 
            frio = 25
            print('El total a pagar es: $', frio)
            desicion = input("¿Desea algo más?")
        elif tipo == 3: 
            frappe = 25
            print('El total a pagar es: $', frappe)
            desicion = input("¿Desea algo más?")
        else: 
            print()
            print('El valor ingresado no esta dentro del rango. Pruebe de nuevo')
            desicion = 'Si'
# Out:
# Bienvenido a la Cafetería "  "
# Seleccione la opción a escoger (Ingrese el número):
# 1. Cafes:
# 2. Cuernitos
# 3. Postres:
# 1
# Los cafés disponibles son:
# 1. Caliente: $25
# 2. Frío: $25
# 3. Frappe: $30
# Para escoger, ingresa el número: 5
# El valor ingresado no esta dentro del rango. Pruebe de nuevo
# Seleccione la opción a escoger (Ingrese el número):
# 1. Cafes:
# 2. Cuernitos
# 3. Postres:
# 3
# Seleccione la opción a escoger (Ingrese el número):
# 1. Cafes:
# 2. Cuernitos
# 3. Postres:
# 3
# Seleccione la opción a escoger (Ingrese el número):
# 1. Cafes:
# 2. Cuernitos
# 3. Postres:
# 1
# Los cafés disponibles son:
# 1. Caliente: $25
# 2. Frío: $25
# 3. Frappe: $30
# Para escoger, ingresa el número: 2
# El total a pagar es: $ 25
# ¿Desea algo más?2

# %%
def mostrar():
    print('Seleccione la opción a escoger: \n1. Cafes: \n2. Cuernitos \n3. Postres: ')
    
def escoger():
    return escoge = int(input())
    
mostrar()
escoger()
