# %%
print('Bienvenido a la Cafetería "  "')

desicion = 'Si'
contador = 0

while desicion == 'Si':
    print('Seleccione la opción a escoger (Ingrese el número): \n1. Cafes: \n2. Cuernitos \n3. Postres: ')
    opc = int(input())
    
    if opc == 1:
        
        print('Los cafés disponibles son: \n1. Caliente: $25  \n2. Frío: $25 \n3. Frappe: $30')
        tipo = int(input('Para escoger, ingresa el número: '))
        
        if tipo == 1:
            caliente = 25
            contador += caliente
            print()
            desicion = input("¿Desea algo más? ")
        elif tipo == 2: 
            frio = 25
            contador += frio
            print()
            desicion = input("¿Desea algo más? ")
        elif tipo == 3: 
            frappe = 30
            contador += frappe
            print()
            desicion = input("¿Desea algo más? ")
        else: 
            print()
            print('El valor ingresado no esta dentro del rango. Pruebe de nuevo')
            desicion = 'Si'
            
    elif opc == 2: 
        
        print('Los cuernitos disponibles son: \n1. Atún: $25  \n2. Jamón y queso: $25 \n3. Carne y queso: $30')
        tipo = int(input('Para escoger, ingresa el número: '))
        
        if tipo == 1:
            atun = 20
            contador += atun
            print()
            desicion = input("¿Desea algo más? ")
        elif tipo == 2: 
            jam_queso = 25
            contador += jam_queso
            print()
            desicion = input("¿Desea algo más? ")
        elif tipo == 3: 
            carn_queso = 30
            contador += carn_queso
            print()
            desicion = input('¿Desea algo más? ')
        else: 
            print()
            print('El valor ingresado no esta dentro del rango. Pruebe de nuevo')
            desicion = 'Si'
        
    elif opc == 3: 
        
        print('Los postres disponibles son: \n1. Pastel de Chocolate: $25  \n2. Pastel de elote: $25 \n3. Pay de queso: $30')
        tipo = int(input('Para escoger, ingresa el número: '))
        
        if tipo == 1:
            pastel_choc = 25
            contador += pastel_choc
            print()
            desicion = input("¿Desea algo más? ")
        elif tipo == 2: 
            pastel_elote = 25
            contador += pastel_elote
            print()
            desicion = input("¿Desea algo más? ")
        elif tipo == 3: 
            pay_queso = 25
            contador += pay_queso
            desicion = input("¿Desea algo más? ")
        else: 
            print()
            print('El valor ingresado no esta dentro del rango. Pruebe de nuevo')
    else: 
        print()
        print('El número ingresado esta fuera de rango')
        
    print('El total a pagar es: $', contador )
# Out:
# Bienvenido a la Cafetería "  "
# Seleccione la opción a escoger (Ingrese el número):
# 1. Cafes:
# 2. Cuernitos
# 3. Postres:
# 1
# Los cafés disponibles son:
# 1. Caliente: $25
# 2. Frío: $25
# 3. Frappe: $30
# Para escoger, ingresa el número: 2
#
# ¿Desea algo más? Si
# El total a pagar es: $ 25
# Seleccione la opción a escoger (Ingrese el número):
# 1. Cafes:
# 2. Cuernitos
# 3. Postres:
# 2
# Los cuernitos disponibles son:
# 1. Atún: $25
# 2. Jamón y queso: $25
# 3. Carne y queso: $30
# Para escoger, ingresa el número: 3
#
# ¿Desea algo más? Si
# El total a pagar es: $ 55
# Seleccione la opción a escoger (Ingrese el número):
# 1. Cafes:
# 2. Cuernitos
# 3. Postres:
# 3
# Los postres disponibles son:
# 1. Pastel de Chocolate: $25
# 2. Pastel de elote: $25
# 3. Pay de queso: $30
# Para escoger, ingresa el número: 3
# ¿Desea algo más? No
# El total a pagar es: $ 80
